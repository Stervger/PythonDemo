# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
df = pd.read_excel('C:/Users/Administrator/Desktop/pandas_practise/arima_data.xls',index_col = 0);
df.head()
# Out:
#               销量
# 日期
# 2015-01-01  3023
# 2015-01-02  3039
# 2015-01-03  3056
# 2015-01-04  3138
# 2015-01-05  3188

# %%
df.plot()
plt.show()

# %%
D_data = df.diff()

# %%
D_data = D_data.dropna()

# %%
D_data.plot()
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(D_data['销量'])
plt.show()

# %%
plot_acf(df['销量'])
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df['销量'])
# Out:
# (1.8137710150945274,
#  0.9983759421514264,
#  10,
#  26,
#  {'1%': -3.7112123008648155,
#   '5%': -2.981246804733728,
#   '10%': -2.6300945562130176},
#  299.46989866024177)

# %%
adfuller(D_data['销量'])
# Out:
# (-3.1560562366723537,
#  0.022673435440048798,
#  0,
#  35,
#  {'1%': -3.6327426647230316,
#   '5%': -2.9485102040816327,
#   '10%': -2.6130173469387756},
#  287.5909090780334)

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox

# %%
acorr_ljungbox(D_data['销量'],lags = 1)
# Out:
# (array([11.30402222]), array([0.00077339]))
