# %% [markdown]
# <h1>02.Python语法基础<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#编程语言" data-toc-modified-id="编程语言-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>编程语言</a></span></li><li><span><a href="#字符编码" data-toc-modified-id="字符编码-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>字符编码</a></span></li><li><span><a href="#注释" data-toc-modified-id="注释-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>注释</a></span><ul class="toc-item"><li><span><a href="#单行注释" data-toc-modified-id="单行注释-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>单行注释</a></span></li><li><span><a href="#多行注释" data-toc-modified-id="多行注释-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>多行注释</a></span></li></ul></li><li><span><a href="#换行" data-toc-modified-id="换行-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>换行</a></span></li><li><span><a href="#变量、常量和运算符" data-toc-modified-id="变量、常量和运算符-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>变量、常量和运算符</a></span><ul class="toc-item"><li><span><a href="#变量" data-toc-modified-id="变量-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>变量</a></span></li><li><span><a href="#常量" data-toc-modified-id="常量-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>常量</a></span></li><li><span><a href="#运算符" data-toc-modified-id="运算符-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>运算符</a></span></li></ul></li><li><span><a href="#基本数据类型" data-toc-modified-id="基本数据类型-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>基本数据类型</a></span><ul class="toc-item"><li><span><a href="#整形" data-toc-modified-id="整形-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>整形</a></span></li><li><span><a href="#浮点" data-toc-modified-id="浮点-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>浮点</a></span></li><li><span><a href="#布尔" data-toc-modified-id="布尔-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>布尔</a></span></li><li><span><a href="#字符串" data-toc-modified-id="字符串-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>字符串</a></span></li><li><span><a href="#强悍的字符串切片" data-toc-modified-id="强悍的字符串切片-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>强悍的字符串切片</a></span></li><li><span><a href="#Python字符串常用的方法" data-toc-modified-id="Python字符串常用的方法-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Python字符串常用的方法</a></span></li></ul></li><li><span><a href="#常用内置函数" data-toc-modified-id="常用内置函数-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>常用内置函数</a></span></li><li><span><a href="#导入模块中的函数" data-toc-modified-id="导入模块中的函数-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>导入模块中的函数</a></span></li><li><span><a href="#random模块" data-toc-modified-id="random模块-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>random模块</a></span></li><li><span><a href="#输入" data-toc-modified-id="输入-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>输入</a></span></li><li><span><a href="#输出" data-toc-modified-id="输出-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>输出</a></span><ul class="toc-item"><li><span><a href="#占位符" data-toc-modified-id="占位符-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>占位符</a></span></li><li><span><a href="#填充与对齐" data-toc-modified-id="填充与对齐-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>填充与对齐</a></span></li><li><span><a href="#类型与精度" data-toc-modified-id="类型与精度-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>类型与精度</a></span></li><li><span><a href="#如何合用？" data-toc-modified-id="如何合用？-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>如何合用？</a></span></li><li><span><a href="#高端用法" data-toc-modified-id="高端用法-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>高端用法</a></span></li><li><span><a href="#番外篇" data-toc-modified-id="番外篇-11.6"><span class="toc-item-num">11.6&nbsp;&nbsp;</span>番外篇</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Python语法基础

# %% [markdown]
# ## 编程语言
#
# 计算机语言种类很多，总体可以分为三大类，分别是高级语言、汇编语言、机器语言。
#
# C语言属于哪种呢？
#
# Python属于哪种呢？

# %% [markdown]
# Python是一个结合解释性、编译性、互动性和面向对象的高层次脚本语言，也是一种高级语言。由于Python易学习，并且具有广泛而丰富的标准库及第三方库的特点，使它可以和其它语言很好的融合在一起，所以也被称为“胶水语言”。Python的设计目标之一是让代码具备高度的可阅读性，它设计时尽量使用其它语言经常使用的标点符号和英文单字，让代码看起来整洁美观，而不像其他如C、Pascal等静态语言那样需要重复书写声明语句，经常出现特殊情况和意外。

# %% [markdown]
# ## 字符编码
#
# 什么是字符编码？
#
# 你知道哪些字符编码？
#
# * Python3安装后，系统默认其源码文件为UTF-8编码。在此编码下，全世界大多数语言的字符可以同时在字符串和注释中得到准确编译。
# * 大多数情况下，通过编辑器编写的Python代码默认保存UTF-8编码脚本文件，系统通过Python执行该文件时就不会出错。但是如果编辑器不支持UTF-8编码的文件，或者团队合作时有人使用了其他编码格式，Python3就无法自动识别脚本文件，造成程序执行错误，这时候对Python脚本文件进行编码声明就尤为重要了。比如，GBK脚本文件在没有编码声明时，执行文件时就会出错，经编码声明后脚本就可以正常执行。
# * 为源文件指定特定的字符编码，需要在文件的首行或者第二行插入一行特殊的注释行，通常使用的编码声明格式如下：

# %%
#-*-coding:utf-8-*-

# %% [markdown]
# ## 注释

# %% [markdown]
# ### 单行注释

# %%
#print("Hello World")
print("Hello Python")

# %% [markdown]
# ### 多行注释

# %%
'''print("Hello World")
print("Hello Python")'''

# %%
"""print("Hello World")
print("Hello Python")"""

# %% [markdown]
# ## 换行
# 一般情况下是一行写完一条语句，但是如果语句太长，就会使得语句冗长不很美观，通过反斜杠（\）可以实现一个长语句的换行。

# %%
total = applePrice + \
          orangePrice + \
          milkPrice

# %% [markdown]
# ## 变量、常量和运算符
#
# ### 变量
# **变量（变量名必须是大小写英文、数字和_的组合，且<font color='red'>不能</font>用数字开头）**
# 在Python中，不需要事先声明变量名及其类型，直接赋值即可创建各种类型的对象变量。这一点适用于Python任意类型的对象。
#
# 例如语句：
#
# ```
# x=3
# ```
#
# 创建了整型变量x，并赋值为3

# %%
x=3
print(x)

# %% [markdown]
# 在Python中，等号=是赋值语句，可以把任意数据类型赋值给变量，同一个变量可以反复赋值，而且<font color='red'>可以是**不同类型**的变量。</font>
#
# 赋值语句的执行过程是：首先把等号右侧表达式的值计算出来，然后在内存中寻找一个位置把值存放进去，最后创建变量并指向这个内存地址。
#
# Python中的变量并不直接存储值，而是存储了值的内存地址或者引用，这也是变量类型随时可以改变的原因。所以Python允许多个变量指向同一个值
#
# ** Python中可以使用 <font color='red'>id</font> 命令查看变量的地址。**

# %%
a=123
print(a)
print(id(a))

a='ABC'
print(a)
print(id(a))

# %% [markdown]
# 最后，理解变量在计算机内存中的表示也非常重要。当我们写：
# ```
#   a = 123
# ```
# 时，Python解释器干了两件事情：
# * 在内存中创建了一个值为123的整数；
# * 在内存中创建了一个名为a的变量，并把它指向123。
#
# 也可以把一个变量a赋值给另一个变量b，这个操作实际上是把变量b指向变量a所指向的数据，例如下面的代码：

# %%
a=123
print(a)
print(id(a))
b=a
print(b)
print(id(b))

# %% [markdown]
# **关于变量命名**
#
# * 变量名必须以字母或下划线开头，但以下划线开头的变量在Python中有特殊含义；
# * 变量名中不能有空格以及标点符号（括号、引号、逗号、斜线、反斜线、冒号、句号、问号等等）；
# * 不能使用关键字作变量名，可以导入keyword模块后使用print(keyword.kwlist)查看所有Python关键字；
# * 变量名对英文字母的大小写敏感，例如student和Student是不同的变量。
# * 不建议使用系统内置的模块名、类型名或函数名以及已导入的模块名及其成员名作变量名，这将会改变其类型和含义，可以通过dir(\__builtin\__)查看所有内置模块、类型和函数；

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# dir() 函数不带参数时，返回当前范围内的变量、方法和定义的类型列表；带参数时，返回参数的属性、方法列表。

# %%
dir()

# %%
dir(__builtin__)

# %% [markdown]
# ### 常量
#
# 所谓常量就是不能变的变量，比如常用的数学常数π就是一个常量。在Python中，通常用全部大写的变量名表示常量。
#
# 但事实上PI仍然是一个变量，Python根本没有任何机制保证PI不会被改变，所以，用全部大写的变量名表示常量只是一个习惯上的用法，如果你一定要改变变量PI的值，也没人能拦住你。

# %%
PI = 3.14159265359

# %% [markdown]
# <font color='red'>不光任何自定义变量可以随时被修改，连系统自带的函数和对象都可以随时被修改，比如，一旦你重定义了print为一个变量，那么你就没有办法打印了！千万谨慎！！</font>

# %%
print=5
print('aaa')

# %% [markdown]
# 测试完上述语句后请重新运行python或在jupyter里面restart kernel，再检查print的类型：

# %%
print

# %% [markdown]
# ###  运算符
# * 数学运算符
#
# 以下假设变量： a=10，b=21：
#
#
#  | 算术运算符 |                  描述                       |           示例           |
#  |:------:|:------------------------------------------------:|:------------------------:|
#  |    +   | 加法运算，将运算符两边的操作数增加。             | a + b = 31               |
#  |    -   | 减法运算，将运算符左边的操作数减去右边的操作数。 | a – b = -11              |
#  |    *   | 乘法运算，将运算符两边的操作数相乘。             | a * b = 210              |
#  |    /   | 除法运算，用左操作数除右操作数。                 | b / a = 2.1              |
#  |    %   | 模运算，用左操作数除以右操作数并返回余数。       | b % a = 1                |
#  |   **   | 进行指数(幂)计算。                               | a ** b，表示10的21次幂   |
#  |   //   | 地板除 - 返回商的整数部分（向下取整）            |  b // a = 2 -9 // 2 = -5 |
#
#
# 请自行练习所有的算术运算符：

# %%
10/3

# %% [markdown]
# * 关系运算符：==, !=, >, <, >=, <=

# %%
12 != 11

# %% [markdown]
# * 逻辑运算符：and，or，not

# %%
not(12 != 11)

# %% [markdown]
# * 位运算符：与&，或|，异或^，取反～，左移<<, 右移>>

# %%
1<<1
# Out:
# 2

# %% [markdown]
# * 身份运算符用于比较两个对象的内存地址。常用的有两个身份运算符：is 和 is not

# %%
a=20
b=20
print(id(a))
print(id(b))
print(a is b)
# Out:
# 140730812896672
# 140730812896672
# True

# %% [markdown]
# * 成员运算符用于测试给定值是否为序列中的成员，例如字符串，列表或元组，两个：in 和 not in

# %%
'h' in 'hello world'
# Out:
# True

# %% [markdown]
# ## 基本数据类型
#
# ### 整形
#
# Python支持任意大的数字，具体可以大到什么程度仅受内存大小的限制。

# %%
9999**9999
# Out:
# ...

# %% [markdown]
# ### 浮点
#
# 由于精度的问题，对于浮点运算可能会有一定的误差，应尽量避免在浮点数之间直接进行相等性测试，而是应该以二者之差的绝对值是否足够小作为两个浮点数是否相等的依据。
#
# 在数字的算术运算表达式求值时会进行隐式的类型转换，如果存在复数则都变成复数，如果没有复数但是有实数就都变成实数，如果都是整数则不进行类型转换。

# %%
0.4-0.1 == 0.3             #应尽量避免直接比较两个实数是否相等
# Out:
# False

# %%
0.4-0.1
# Out:
# 0.30000000000000004

# %%
abs(0.4-0.1 - 0.3) < 1e-6    #这里1e-6表示10的-6次方
# Out:
# True

# %% [markdown]
# * Python 3.6.x支持在数字中间位置使用单个下划线作为分隔来提高数字的可读性，类似于数学上使用逗号作为千位分隔符。
# * 在Python数字中单个下划线可以出现在中间任意位置，但不能出现开头和结尾位置，也不能使用多个连续的下划线。

# %%
print(1_000_000)

print(1_2_3_4)

print(1_2 + 3_4j)

print(1_2.3_45)
# Out:
# 1000000
# 1234
# (12+34j)
# 12.345

# %% [markdown]
# ### 布尔

# %%
a=True
print(not(a))

# %% [markdown]
# ### 字符串
#
# 在Python中，没有字符常量和变量的概念，只有字符串类型的常量和变量，单个字符也是字符串。使用单引号、双引号、三单引号、三双引号作为定界符（delimiter）来表示字符串，并且不同的定界符之间可以互相嵌套。

# %%
x = '"Hello world".'                  #使用单引号作为定界符
print(x)
x = "Python is the world's greatest language."   #使用双引号作为定界符
print(x)
x = '''Tom said, "Let's go."'''     #不同定界符之间可以互相嵌套
print(x)
# Out:
# "Hello world".
# Python is the world's greatest language.
# Tom said, "Let's go."

# %% [markdown]
# **字符串的拼接**

# %%
a = 'good '
b = 'morning'
x = a+b             #连接字符串
x
# Out:
# 'good morning'

# %%
a*3+b
# Out:
# 'good good good morning'

# %% [markdown]
# ### 强悍的字符串切片
#
# * 获取Python字符串中的某字符可以使用索引：
# ![image.png](attachment:image.png)

# %%
lang = 'python'
print(lang[0])
print(lang[3])
print(lang[-1])
# Out:
# p
# h
# n

# %% [markdown]
# * 截取字符串中的一段字符串可以使用切片，切片在方括号中使用冒号:来分隔需要截取的首尾字符串的索引，方式是<font color='red'>**包括开头，不包括结尾**</font>

# %%
print(lang[1:4])
print(lang[1:-1])
# Out:
# yth
# ytho

# %% [markdown]
# * 当尾索引没有给出时，默认截取到字符串的末尾

# %%
lang[1:]
# Out:
# 'ython'

# %% [markdown]
# * 当头索引没有给出的时候默认从字符串开头开始截取

# %%
lang[:3]
# Out:
# 'pyt'

# %% [markdown]
# * 当尾索引和头索引都没有给出的时候，默认返回整个字符串

# %%
lang[:]
# Out:
# 'python'

# %% [markdown]
# * 当尾索引大于总的字符串长度时，默认只截取到字符串末尾，很明显使用这种方法来截取一段到字符串末尾的子字符串是非常不明智的，应该是不给出尾索引才是最佳实践

# %%
lang[3:100]
# Out:
# 'hon'

# %% [markdown]
# * 当头索引为负数时，则是指从字符串的尾部开始计数，最末尾的字符记为-1，以此类推，因此此时应该注意尾索引的值，尾索引同样可以为负数，如果尾索引的值指明的字符串位置小于或等于头索引，此时会报错。

# %%
lang[-2:]
# Out:
# 'on'

# %%
lang[-2,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-d5ec7c75eb7b> in <module>
# ----> 1 lang[-2,2]
#
# TypeError: string indices must be integers

# %% [markdown]
# * 完全版的切片，有三个参数，第三个是步长（类似于C语言里面的for循环），巧妙使用步长参数可以轻易的反转一个字符串：

# %%
lang[::-1]
# Out:
# 'nohtyp'

# %% [markdown]
# **<font color='blue'>切片的思想在数组（list）和Numpy以及Pandas等数据分析库中是非常非常普遍的。一定要熟悉和掌握。</font>**

# %% [markdown]
# ### Python字符串常用的方法
#
# * 使用len()方法获取字符串长度

# %%
len(lang)
# Out:
# 6

# %% [markdown]
# * 使用in操作符判断某个子字符是否在字符串中

# %%
'p' in lang
# Out:
# True

# %%
'aaa' in lang
# Out:
# False

# %% [markdown]
# * 使用max()和min()方法获取字符串中编码极值对应的字符

# %%
max(lang)
# Out:
# 'y'

# %%
min(lang)
# Out:
# 'h'

# %% [markdown]
# * 使用*操作符对字符串进行重复

# %%
(lang+' ')*3
# Out:
# 'python python python '

# %%
lang+' '*3
# Out:
# 'python   '

# %% [markdown]
# * 使用str()方法将其他数据类型转化为字符串

# %%
str(3.14159)
# Out:
# '3.14159'

# %% [markdown]
# * 使用split()方法将字符串按照指定的字符串分隔，返回数组

# %%
"I am a good man".split(' ')
# Out:
# ['I', 'am', 'a', 'good', 'man']

# %% [markdown]
# * 使用join()方法连接字符串数组为一个完整的字符串

# %%
a="I am a good man".split(' ')
'.'.join(a)
# Out:
# 'I.am.a.good.man'

# %% [markdown]
# * 使用count()方法获取某个字符在字符串中出现的次数

# %%
'aaa111223a'.count('a')
# Out:
# 4

# %% [markdown]
# * 使用index()方法获取某个字符在字符串中首次出现的位置的索引

# %%
lang.index('p')
# Out:
# 0

# %%
lang.index('n')
# Out:
# 5

# %% [markdown]
# * 使用strip()方法去除字符串头尾的特定字符，默认去除空格和换行

# %%
lang='  python \n'
lang.strip()
# Out:
# 'python'

# %%
lang
# Out:
# '  python \n'

# %% [markdown]
# **更多的字符串方法请使用dir()函数**

# %%
dir(lang)

# %% [markdown]
# 请自行尝试上面查到的函数：

# %% [markdown]
# ## 常用内置函数
# 内置函数（BIF，built-in functions）是Python内置对象类型之一，不需要额外导入任何模块即可直接使用，这些内置对象都封装在内置模块builtins之中，用C语言实现并且进行了大量优化，具有非常快的运行速度，推荐优先使用。可以使用help函数查询各个函数的使用。

# %% [markdown]
# * abs()

# %%
abs(-5)

# %% [markdown]
# * len()

# %%
len('12345')

# %% [markdown]
# * max(), min()

# %%
max('12345')

# %%
min('12345')

# %% [markdown]
# * id()        查看变量的地址

# %%
a=3.14159
id(a)
# Out:
# 1770085321008

# %% [markdown]
# * type()         查看变量的类型

# %%
type(a)
# Out:
# float

# %% [markdown]
# * eval() 执行字符串语句

# %%
eval('3+5')
# Out:
# 8

# %% [markdown]
# 还有很多的强大的内置函数需要在大家掌握了更多的Python知识后再介绍。

# %% [markdown]
# ## 导入模块中的函数

# %%
import math

# %%
dir(math)        #dir 函数可以查看一个包中所有的函数和对象
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
math.pi

# %%
math.e

# %% [markdown]
# **想直接使用函数，不想加上模块的名字？可以的**

# %%
from math import pi

# %%
pi

# %% [markdown]
# **一个不够？**

# %%
from math import sin, cos

# %%
sin(0.5*pi)

# %%
cos(0.25*pi)

# %% [markdown]
# **我想全都要？**

# %%
from math import *

# %%
log(e)
# Out:
# 1.0

# %% [markdown]
# **完蛋，重名了，还是留下模块的名字，但是能不能好记点？**

# %%
import math as m

# %%
m.sqrt(2)

# %% [markdown]
# ## random模块
# python自带random模块，用于生成随机数

# %%
import random

# %%
dir(random)

# %% [markdown]
# **random.random()**
#
# 生成0~1的随机浮点数

# %%
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.6148733527625525
# 0.09239214964873299
# 0.6487800324526378

# %% [markdown]
# **random.uniform(a,b)**
#
# 生成指定范围的随机浮点数，a<=n<=b

# %%
print(random.uniform(1,10))
print(random.uniform(1,10))
print(random.uniform(1,10))
# Out:
# 5.658953213884049
# 3.2613775238265506
# 7.768597976430519

# %% [markdown]
# **random.randint(a,b)**
#
# 生成指定范围的随机整数，a<=n<=b

# %%
print(random.randint(1,10))
print(random.randint(1,10))
print(random.randint(1,10))
# Out:
# 5
# 7
# 9

# %% [markdown]
# ## 输入
# input函数负责获取用户的输入，返回总是一个字符串，如果需要获得整数或者浮点，需要自己进行转换

# %%
a=input(' 请输入一个数') 
print(a)

# %%
type(a)

# %%
b=eval(a)
b

# %%
type(b)

# %%
c=int(a)
d=float(a)
d

# %% [markdown]
# ## 输出
# **print是强大且普遍运用的输出语句，和c语言的printf类似。**

# %% [markdown]
# ### 占位符
#
# 使用{}占位，里面可以使用数字，与后面的参数对应，参数可以是一个数组，下标即为占位符里的数字。
#
# 占位符里面也可以是名字，与后面的关键字参数对应，参数也可以是一个字典，key即为占位符里的名字。

# %%
print("{} {}".format("hello", "world"))    # 不指定位置，按默认顺序
print("{0} {1}".format("hello", "world"))  # 指定位置
print("{1} {0} {1}".format("hello", "world")) # 指定位置，可以重用
print('{name},{sex},{age}'.format(age=32,sex='男',name='张三')) # 使用关键字参数指定名字
# Out:
# hello world
# hello world
# world hello world
# 张三,男,32

# %% [markdown]
# ### 填充与对齐
#
# * 填充常跟对齐一起使用
#   * < （默认）左对齐
#   * \> 右对齐
#   * ^ 中间对齐
#
# * 后面带宽度
#
# * :号后面带填充的字符，只能是一个字符，不指定的话默认是用空格填充

# %%
print("12345678")
print('{:>8}'.format('abc'))
print('{:<8}'.format('abc'))
print('{:^8}'.format('abc'))
print('{:-^8}'.format('abc'))
# Out:
# 12345678
#      abc
# abc
#   abc
# --abc---

# %% [markdown]
# ### 类型与精度
#
# * f表示浮点
#    * .2f 小数点后2位
#    * .0f 取整
# * e表示科学计数
# * %表示百分制
# * ，表示金融数字格式
# * b表示二进制
# * d表示十进制（默认）
# * o表示八进制
# * x表示十六进制

# %%
print('{:.2f}'.format(3.14159))
print('{:.0f}'.format(3.9))
print('{:e}'.format(3.14159))
print('{:%}'.format(0.75))
print('{:,}'.format(100000000))
print('{:b}'.format(56))

# %% [markdown]
# ### 如何合用？

# %%
print('{:>18%}'.format(0.2))
print('{:<18%}'.format(0.2))

# %%
print('{:-^18.3f}'.format(3.14159))

# %% [markdown]
# ### 高端用法

# %%
x='Pi',3.1415926
print('{0}的值是:{1:-^18.7f}'.format(*x))  # 因为x是一个地址，*x = 'Pi',3.1415926
print('{0}的值是:{1:^18.7f}'.format('Pi',3.1415926))

# %%
p=['kzc',18]
'{0[0]},{0[1]}'.format(p)

# %%
p=['kzc',18]
'{0[0]},{0[1]}'.format(*p)

# %% [markdown]
# ### 番外篇

# %% [markdown]
# 如果要把格式化后的结果保存在字符串里，而不是打印输出，也可以直接使用format函数：

# %%
x=format(3.1415926, '-^18.7f')     
x

# %% [markdown]
# 或者使用print函数的参数部分，也可以：

# %%
x='{0}的值是:{1:^18.7f}'.format('Pi',3.1415926)
x

# %% [markdown]
# sep参数，用于指定分隔符，默认是空格分割

# %%
print(1,2,3,4)
print(1,2,3,4,sep='\t')

# %% [markdown]
# 输出一个数字换一行该怎么实现？

# %% [markdown]
# end参数，用于指定行末的字符，默认是换行符，可以改为空格或者空字符，在循环中就可以在同一行里继续输出了：

# %%
for i in range(5):
    print(i)

# %%
for i in range(5):
    print(i, end='')

# %% [markdown]
# file参数，输出到文件：

# %%
with open('./a.txt','w+') as fp:     # with语句会自动关闭文件
    print('hello file', file=fp)

# %%
# !type a.txt

# %%
str()
